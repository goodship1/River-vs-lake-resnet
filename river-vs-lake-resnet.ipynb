# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image
from keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import glob
from tensorflow.keras.regularizers import l2
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image


import os
import cv2


for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_22.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_53.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_69.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_68.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_51.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_88.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_4.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_75.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_12.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_16.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_72.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_58.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_62.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_2.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_45.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_7.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_85.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_65.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_5.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_86.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_36.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_18.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_33.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_19.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_89.png
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_31.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_27.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_66.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_61.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_92.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_11.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_39.JPG
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_74.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_79.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_28.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_44.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_14.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_48.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_41.JPG
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_10.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_81.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_47.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_30.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_99.jpeg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_77.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_59.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_23.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_60.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_63.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_34.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_94.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_50.JPG
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_32.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_70.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_83.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_98.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_21.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_95.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_93.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_25.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_17.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_87.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_96.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_15.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_54.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_90.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_1.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_13.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_43.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_40.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_91.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_97.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_56.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_55.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_42.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_26.jpeg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_8.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_84.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_38.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_67.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_46.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_49.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_3.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_100.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_20.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_64.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_52.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_24.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_73.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_76.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_29.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_57.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_35.png
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_37.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_6.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_9.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_71.jpg
# /kaggle/input/river-vs-lake/River vs Lake/river water/Image_82.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_22.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_53.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_69.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_40.png
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_51.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_88.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_4.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_75.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_16.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_72.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_58.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_62.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_2.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_45.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_7.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_85.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_65.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_5.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_12.jpeg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_36.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_18.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_33.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_19.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_31.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_27.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_66.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_61.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_11.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_39.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_74.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_79.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_26.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_28.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_44.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_14.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_48.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_41.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_10.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_81.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_47.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_30.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_77.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_59.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_23.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_60.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_63.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_34.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_50.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_32.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_70.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_83.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_98.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_21.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_95.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_17.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_99.png
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_15.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_90.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_1.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_13.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_89.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_43.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_91.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_97.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_56.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_78.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_25.jpeg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_35.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_80.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_42.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_94.png
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_8.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_84.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_38.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_67.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_46.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_49.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_3.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_100.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_20.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_64.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_52.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_24.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_73.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_76.JPG
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_29.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_57.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_37.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_6.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_9.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_71.jpg
# /kaggle/input/river-vs-lake/River vs Lake/lake water/Image_82.jpg

# %% [markdown]
# # **** Data Exploration ****

# %%
 #Define the path to your dataset
dataset_dir = '/kaggle/input/river-vs-lake/River vs Lake'

# Initialize lists to store data and labels
X = []
y = []

# Create a list to store class labels
class_labels = []

# Iterate through the subdirectories and load the images and labels
for class_folder in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_folder)
    if os.path.isdir(class_path):
        # Load images from the class folder
        image_paths = glob.glob(os.path.join(class_path, '*.jpeg'))  # Assuming your images have .jpeg extension
        X.extend(image_paths)
        class_labels.extend([class_folder] * len(image_paths))

# Check the class distribution
class_distribution = Counter(class_labels)

# Create a bar chart for class distribution
plt.bar(class_distribution.keys(), class_distribution.values())
plt.xlabel('Class Labels')
plt.ylabel('Number of Samples')
plt.title('Class Distribution')
plt.xticks(rotation=45)
plt.show()

# Create a pie chart for class distribution
plt.pie(class_distribution.values(), labels=class_distribution.keys(), autopct='%1.1f%%')
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# Data set seems balanced

# %% [markdown]
# ****Overview of the data set ****

# %%
#Display the data set of xray models.
training = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)


training_data = training.flow_from_directory(
        '/kaggle/input/river-vs-lake/River vs Lake',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=20,#Creates the batch size 
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels


def displayimages(numberofimages):
        for _ in range(numberofimages):
            img, label = training_data.next()
            print(img.shape)
            plt.imshow(img[0])
            plt.show()

            
displayimages(10)# Displays the first 100 training images.
# Out:
# Found 190 images belonging to 2 classes.
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (20, 150, 150, 3)
# (10, 150, 150, 3)

# %% [markdown]
# **** Breaking up the data into test , train , validation ****

# %%
# Main directory containing the subdirectories for the two classes
main_directory = '/kaggle/input/river-vs-lake/River vs Lake'
target_size = (224, 224)

# Define the batch size (e.g., 32)
batch_size = 32

# Data augmentation settings
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.10  # Specify the validation split
)

# Create a data generator for both training and validation
train_generator = train_datagen.flow_from_directory(
    main_directory,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    main_directory,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'  # Use 'validation' subset for validation data
)
# Out:
# Found 172 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model (you should adjust the number of epochs and other parameters as needed)
model.fit(train_generator, epochs=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step
# Epoch 1/10
# 6/6 [==============================] - 107s 15s/step - loss: 1.5475 - accuracy: 0.6163
# Epoch 2/10
# 6/6 [==============================] - 84s 13s/step - loss: 0.4597 - accuracy: 0.7965
# Epoch 3/10
# 6/6 [==============================] - 82s 13s/step - loss: 0.4085 - accuracy: 0.8547
# Epoch 4/10
# 6/6 [==============================] - 82s 15s/step - loss: 0.3488 - accuracy: 0.8779
# Epoch 5/10
# 6/6 [==============================] - 85s 13s/step - loss: 0.3035 - accuracy: 0.8895
# Epoch 6/10
# 6/6 [==============================] - 76s 12s/step - loss: 0.3744 - accuracy: 0.8488
# Epoch 7/10
# 6/6 [==============================] - 73s 12s/step - loss: 0.3050 - accuracy: 0.8953
# Epoch 8/10
# 6/6 [==============================] - 73s 13s/step - loss: 0.1817 - accuracy: 0.9302
# Epoch 9/10
# 6/6 [==============================] - 81s 13s/step - loss: 0.0803 - accuracy: 0.9826
# Epoch 10/10
# 6/6 [==============================] - 84s 13s/step - loss: 0.1408 - accuracy: 0.9535

# %%
# Load and preprocess an image (replace 'image_path' with the path to your image)
img_path = '/kaggle/input/river-vs-lake/River vs Lake/lake water/Image_1.jpg'  # Change this to the path of your image
img = image.load_img(img_path, target_size=(224, 224))  # Adjust target_size if necessary
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)  # Add a batch dimension

# Normalize the image (if your training data was rescaled, you should do the same here)
img = img / 255.0

# Make predictions
predictions = model.predict(img)

# The 'predictions' variable contains the model's output; it might look like [[0.725]] for example.

# If it's a binary classification task, you can threshold the prediction
# For example, if the prediction is >= 0.5, you can consider it as class 1, and < 0.5 as class 0.
class_index = 1 if predictions[0][0] >= 0.5 else 0

# Now, 'class_index' will contain the predicted class (0 or 1).

if class_index == 0:
    print("Predicted: River")
else:
    print("Predicted: Lake")
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: River
